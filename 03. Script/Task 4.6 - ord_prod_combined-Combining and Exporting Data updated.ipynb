# %% [markdown]
# # Task 4.6: Combining & Exporting Data

# %% [markdown]
# ## This script contains the following contents:

# %% [markdown]
# ### 1. Importing Data

# %% [markdown]
# ### 2. Check the Output of Dataframes

# %% [markdown]
# ### 3. Merge the Dataframes

# %% [markdown]
# ### 4. Confirm the Results of the Merged Data

# %% [markdown]
# ### 5. Export the File in Picket Format

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### 1. Importing Data

# %%
# This command will import my saved CSV files within a certain folder
df = pd.read_csv(r'/Users/obinwannealisigwe/Desktop/Python/Achievement_4_Project_Obi/02. Data/Original Data/orders.csv', index_col=False)

# %%
# This command tells python to remember a main folder path_Original Data
path_1= r'/Users/obinwannealisigwe/Desktop/Python/Achievement_4_Project_Obi/02. Data/Original Data'

# %%
# This command tells python to remember a main folder path_Prepared Data
path = r'/Users/obinwannealisigwe/Desktop/Python/Achievement_4_Project_Obi/02. Data/Prepared Data'

# %%
path
# Out:
# '/Users/obinwannealisigwe/Desktop/Python/Achievement_4_Project_Obi/02. Data/Prepared Data'

# %%
# Import the “products.csv” file into Jupyter
df_prod = pd.read_csv(os.path.join(path_1, 'products.csv'), index_col = False)

# %%
# Importing the 'df_ord_prior' file into the Jupyter 
df_ord_prior = pd.read_csv(os.path.join(path_1, 'orders_products_prior.csv'), index_col = False)

# %%
# Importing the orders_products_combined
df_ord_combined = pd.read_pickle(os.path.join(path, 'orders_products_combined.pkl'))

# %%
# Importing the product_checked
df_prod_checked = pd.read_csv(os.path.join(path, 'products_checked.csv'), index_col = False)

# %% [markdown]
# ### 2. Checking the Output of Dataframes

# %%
# Check the Output: df_prod
df_prod.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Checking the Stats
df_prod.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %%
df_prod.shape
# Out:
# (49693, 5)

# %%
# Output for df_ord_combined
df_ord_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           0   2539329        1             1                   2
# 2           0   2539329        1             1                   2
# 3           0   2539329        1             1                   2
# 4           0   2539329        1             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
df_ord_combined.shape
# Out:
# (32434489, 11)

# %% [markdown]
# ### 3. Merge the Dataframes

# %%
# drop unnamed df_ord_combined
df_ord_combined = df_ord_combined.drop(columns = ['Unnamed: 0', '_merge'])

# %%
# merge df_prod_checked and df_ord_combined
df_merged = df_prod_checked.merge(df_ord_combined, on = 'product_id', indicator = True)

# %%
df_merged = df_merged.drop(columns = ['Unnamed: 0'])

# %%
df_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge
# ...

# %% [markdown]
# ### 4. Confirm Results of the Merged Data

# %%
df_merged
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id  order_number  orders_day_of_week  \
# ...

# %%
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# Export data "pkl"
df_merged.to_pickle(os.path.join(path,'ord_prod_combined.pkl'))
